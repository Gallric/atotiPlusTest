# %%
import pandas as pd
import json

# %%
import atoti as tt

session = tt.Session()
# Out:
# Welcome to atoti 0.7.0!
#
# By using this community edition, you agree with the license available at https://docs.atoti.io/latest/eula.html.
# Browse the official documentation at https://docs.atoti.io.
# Join the community at https://www.atoti.io/register.
#
# atoti collects telemetry data, which is used to help understand how to improve the product.
# If you don't wish to send usage data, set the ATOTI_DISABLE_TELEMETRY environment variable to True.
#
# You can hide this message by setting the ATOTI_HIDE_EULA_MESSAGE environment variable to True.

# %%
# load data using Python JSON module
with open('data/test.json','r') as f:
    dataTest = json.loads(f.read())

# Flatten data
df_nested_list_test = pd.json_normalize(dataTest, 
                                  record_path =['members'],
                                  meta=['squadName','homeTown', 'formed', 'secretBase', 'active'])

df_nested_list_test.head()
# Out:
#               name      age secretIdentity  \
# 0     Molecule Man       29      Dan Jukes
# 1  Madame Uppercut       39    Jane Wilson
# 2    Eternal Flame  1000000        Unknown
#
#                                               powers         squadName  \
# 0  [Radiation resistance, Turning tiny, Radiation...  Super hero squad
# 1  [Million tonne punch, Damage resistance, Super...  Super hero squad
# 2  [Immortality, Heat Immunity, Inferno, Teleport...  Super hero squad
#
#      homeTown formed   secretBase active
# 0  Metro City   2016  Super tower   True
# 1  Metro City   2016  Super tower   True
# 2  Metro City   2016  Super tower   True

# %%
# load data using Python JSON module
with open('data/Sensibilidades/JSON/sensitivities.template_general.json','r') as s:
    data_sensis = json.loads(s.read())
    
# Flatten data
df_nested_list_test = pd.json_normalize(data_sensis, record_path =['compute'])

df_nested_list_test.head()
# Out:
#   sub_folder_name                type       prefix rename_scenario  \
# 0    ${FX_subdir}   XML.Sensitivities  ${batch_id}          ^(\w*)
# 1     Projections   CSV.Sensitivities  ${batch_id}             NaN
# 2    ${CR_subdir}   XML.Sensitivities  ${batch_id}          ^(\w*)
# 3    ${FX_subdir}  XML.AdditionalInfo  ${batch_id}             NaN
# 4    ${CR_subdir}  XML.AdditionalInfo  ${batch_id}             NaN
#
#               parser.id                parser.function  \
# 0  Output.Sensitivities  parse_values_per_counterparty
# 1                   NaN                            NaN
# 2  Output.Sensitivities  parse_values_per_counterparty
# 3                   NaN                            NaN
# 4                   NaN                            NaN
#
#   new_measures.pnl_stock_cva_bilateral_contingent  \
# 0              -(contingent_cva - contingent_dva)
# 1              -(contingent_cva - contingent_dva)
# 2              -(contingent_cva - contingent_dva)
# ...
